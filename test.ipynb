# %%
# !pip install -e ".[dev]"
# Out:
# Obtaining file:///Users/r4yen/repos/sundayhack/vibe-widgets
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: anthropic>=0.40.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (0.73.0)
# Requirement already satisfied: anywidget>=0.9.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (0.9.21)
# Requirement already satisfied: pandas>=2.0.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (2.3.3)
# Requirement already satisfied: ipython>=8.12.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (9.7.0)
# Requirement already satisfied: mypy>=1.8.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (1.18.2)
# Requirement already satisfied: pytest-cov>=4.1.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (7.0.0)
# Requirement already satisfied: pytest>=8.0.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (9.0.1)
# Requirement already satisfied: ruff>=0.6.0 in ./venv311/lib/python3.11/site-packages (from vibe-widget==0.1.0) (0.14.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (2.12.4)
# Requirement already satisfied: sniffio in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in ./venv311/lib/python3.11/site-packages (from anthropic>=0.40.0->vibe-widget==0.1.0) (4.15.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in ./venv311/lib/python3.11/site-packages (from anywidget>=0.9.0->vibe-widget==0.1.0) (8.1.8)
# Requirement already satisfied: psygnal>=0.8.1 in ./venv311/lib/python3.11/site-packages (from anywidget>=0.9.0->vibe-widget==0.1.0) (0.15.0)
# Requirement already satisfied: decorator>=4.3.2 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./venv311/lib/python3.11/site-packages (from ipython>=8.12.0->vibe-widget==0.1.0) (5.14.3)
# Requirement already satisfied: mypy_extensions>=1.0.0 in ./venv311/lib/python3.11/site-packages (from mypy>=1.8.0->vibe-widget==0.1.0) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./venv311/lib/python3.11/site-packages (from mypy>=1.8.0->vibe-widget==0.1.0) (0.12.1)
# Requirement already satisfied: numpy>=1.23.2 in ./venv311/lib/python3.11/site-packages (from pandas>=2.0.0->vibe-widget==0.1.0) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv311/lib/python3.11/site-packages (from pandas>=2.0.0->vibe-widget==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv311/lib/python3.11/site-packages (from pandas>=2.0.0->vibe-widget==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv311/lib/python3.11/site-packages (from pandas>=2.0.0->vibe-widget==0.1.0) (2025.2)
# Requirement already satisfied: iniconfig>=1.0.1 in ./venv311/lib/python3.11/site-packages (from pytest>=8.0.0->vibe-widget==0.1.0) (2.3.0)
# Requirement already satisfied: packaging>=22 in ./venv311/lib/python3.11/site-packages (from pytest>=8.0.0->vibe-widget==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv311/lib/python3.11/site-packages (from pytest>=8.0.0->vibe-widget==0.1.0) (1.6.0)
# Requirement already satisfied: coverage>=7.10.6 in ./venv311/lib/python3.11/site-packages (from coverage[toml]>=7.10.6->pytest-cov>=4.1.0->vibe-widget==0.1.0) (7.11.3)
# Requirement already satisfied: idna>=2.8 in ./venv311/lib/python3.11/site-packages (from anyio<5,>=3.5.0->anthropic>=0.40.0->vibe-widget==0.1.0) (3.11)
# Requirement already satisfied: certifi in ./venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->anthropic>=0.40.0->vibe-widget==0.1.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->anthropic>=0.40.0->vibe-widget==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv311/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.40.0->vibe-widget==0.1.0) (0.16.0)
# Requirement already satisfied: comm>=0.1.3 in ./venv311/lib/python3.11/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->vibe-widget==0.1.0) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./venv311/lib/python3.11/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->vibe-widget==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./venv311/lib/python3.11/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->vibe-widget==0.1.0) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv311/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=8.12.0->vibe-widget==0.1.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv311/lib/python3.11/site-packages (from pexpect>4.3->ipython>=8.12.0->vibe-widget==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv311/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.12.0->vibe-widget==0.1.0) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.40.0->vibe-widget==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.40.0->vibe-widget==0.1.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.40.0->vibe-widget==0.1.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./venv311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->vibe-widget==0.1.0) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=8.12.0->vibe-widget==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=8.12.0->vibe-widget==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in ./venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=8.12.0->vibe-widget==0.1.0) (0.2.3)
# Checking if build backend supports build_editable ... done
# Building wheels for collected packages: vibe-widget
#   Building editable for vibe-widget (pyproject.toml) ... done
#   Created wheel for vibe-widget: filename=vibe_widget-0.1.0-py3-none-any.whl size=2152 sha256=c969a1e0046b1e8bb03029dfad516f0a14efc6da96be45bd61113352331caf68
#   Stored in directory: /private/var/folders/v7/wpbns06j4k916t2k95n8wkvm0000gn/T/pip-ephem-wheel-cache-oyid8nnf/wheels/f1/6d/05/33c5bac295959daa2446b78cf877058c30a51c2e61f80b4a36
# Successfully built vibe-widget
# Installing collected packages: vibe-widget
#   Attempting uninstall: vibe-widget
#     Found existing installation: vibe-widget 0.1.0
#     Uninstalling vibe-widget-0.1.0:
#       Successfully uninstalled vibe-widget-0.1.0
# Successfully installed vibe-widget-0.1.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import vibe_widget as vw

df = pd.DataFrame({
    'height': [150, 160, 170, 180, 190],
    'weight': [50, 60, 70, 80, 90]
})

vw.create("an interactive scatterplot of height and weight with zooming", df)
# Out:
# an interactive scatterplot of height and weight with zooming
#
# Data Info: {'columns': ['height', 'weight'], 'dtypes': {'height': 'int64', 'weight': 'int64'}, 'shape': (5, 2), 'sample': [{'height': 150, 'weight': 50}, {'height': 160, 'weight': 60}, {'height': 170, 'weight': 70}]}

# %%
import anywidget
import traitlets


class CounterWidget(anywidget.AnyWidget):
    _esm = """
    function render({ model, el }) {
      let count = () => model.get("value");
      let btn = document.createElement("button");
      btn.classList.add("counter-button");
      btn.innerHTML = `count is ${count()}`;
      btn.addEventListener("click", () => {
        model.set("value", count() + 1);
        model.save_changes();
      });
      model.on("change:value", () => {
        btn.innerHTML = `count is ${count()}`;
      });
      el.appendChild(btn);
    }
    export default { render };
    """
    _css = """
    .counter-button {
      background-image: linear-gradient(to right, #a1c4fd, #c2e9fb);
      border: 0;
      border-radius: 10px;
      padding: 10px 50px;
      color: white;
    }
    """
    value = traitlets.Int(0).tag(sync=True)


w = CounterWidget()
w

# %%
w.value
# Out:
# 7
