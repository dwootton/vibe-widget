# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries and set up the API key.

# %%
# %env ANTHROPIC_API_KEY=sk-XXX
# Out:
# env: ANTHROPIC_API_KEY=sk-XXX

# %%
import vibe_widget as vw
import os


vw.config(
    model="anthropic",  # or "openai", "gemini"
    api_key=os.getenv("ANTHROPIC_API_KEY")
)
# Out:
# Config(model='claude-sonnet-4-5', api_key='sk-XXX', temperature=0.7, streaming=True, mode='standard')

# %% [markdown]
# ## Example 1: PDF Table Extraction
#
# Vibe Widget can automatically extract tables from PDF documents and create interactive visualizations.
#
# Just provide the PDF path and describe what you want to see!

# %%
# Check available PDF files
import os

pdf_files = [f for f in os.listdir('../testdata') if f.endswith('.pdf')]
print(f"📁 Found {len(pdf_files)} PDF file(s) in testdata:")
for f in pdf_files:
    fpath = f'../testdata/{f}'
    size = os.path.getsize(fpath) / 1024
    print(f"   • {f} ({size:.1f} KB)")
# Out:
# 📁 Found 2 PDF file(s) in testdata:
#    • ellipseplanet.pdf (168.4 KB)
#    • foo.pdf (82.2 KB)

# %%
# Create an interactive table from PDF
widget_pdf = vw.create(
    "interactive table showing the data from the PDF with sorting and filtering capabilities",
    data="../testdata/foo.pdf",
    show_progress=True
)

print("\n✨ PDF table extracted and visualized!")
# Out:
# Loading data from source: ../testdata/foo.pdf
# /Users/r4yen/miniconda3/envs/vwidget/lib/python3.10/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4
# Loading data... {'metadata': {'shape': (6, 7), 'columns': ['Cycle \nName', 'KI \n(1/km)', 'Distance \n(mi)', 'Percent Fuel Savings', 'Column_4', 'Column_5', 'Column_6'], 'dtypes': {'Cycle \nName': 'object', 'KI \n(1/km)': 'object', 'Distance \n(mi)': 'object', 'Percent Fuel Savings': 'object', 'Column_4': 'object', 'Column_5': 'object', 'Column_6': 'object'}, 'null_counts': {'Cycle \nName': 0, 'KI \n(1/km)': 0, 'Distance \n(mi)': 0, 'Percent Fuel Savings': 0, 'Column_4': 0, 'Column_5': 0, 'Column_6': 0}, 'sampled': False, 'original_rows': 6}, 'sample': [{'Cycle \nName': '', 'KI \n(1/km)': '', 'Distance \n(mi)': '', 'Percent Fuel Savings': 'Improved \nSpeed', 'Column_4': 'Decreased \nAccel', 'Column_5': 'Eliminate \nStops', 'Column_6': 'Decreased \nIdle'}, {'Cycle \nName': '2012_2', 'KI \n(1/km)': '3.30', 'Distance \n(mi)': '1.3', 'Percent Fuel Savings': '5.9%', 'Column_4': '9.5%', 'Column_5': '29.2%', 'Column_6': '17.4%'}, {'Cycle \nName': '2145_1', 'KI \n(1/km)': '0.68', 'Distance \n(mi)': '11.2', 'Percent Fuel Savings': '2.4%', 'Column_4': '0.1%', 'Column_5': '9.5%', 'Column_6': '2.7%'}, {'Cycle \nName': '4234_1', 'KI \n(1/km)': '0.59', 'Distance \n(mi)': '58.7', 'Percent Fuel Savings': '8.5%', 'Column_4': '1.3%', 'Column_5': '8.5%', 'Column_6': '3.3%'}, {'Cycle \nName': '2032_2', 'KI \n(1/km)': '0.17', 'Distance \n(mi)': '57.8', 'Percent Fuel Savings': '21.7%', 'Column_4': '0.3%', 'Column_5': '2.7%', 'Column_6': '1.2%'}], 'dataframe':   Cycle \nName KI \n(1/km) Distance \n(mi) Percent Fuel Savings  \
# 0                                              Improved \nSpeed
# 1       2012_2        3.30             1.3                 5.9%
# 2       2145_1        0.68            11.2                 2.4%
# 3       4234_1        0.59            58.7                 8.5%
# 4       2032_2        0.17            57.8                21.7%
# 5       4171_1        0.07           173.9                58.1%
#
#             Column_4           Column_5          Column_6
# 0  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 1               9.5%              29.2%             17.4%
# 2               0.1%               9.5%              2.7%
# 3               1.3%               8.5%              3.3%
# 4               0.3%               2.7%              1.2%
# 5               1.6%               2.1%              0.5%  }
# ✨ PDF table extracted and visualized!

# %% [markdown]
# ### What Just Happened?
#
# Behind the scenes, Vibe Widget:
# 1. 🔍 Detected the PDF file format
# 2. 📊 Extracted tables using the PDFExtractor
# 3. 🤖 Generated a custom React component with sorting/filtering
# 4. ✅ Validated and displayed the interactive widget
#
# All from a single line of natural language!

# %% [markdown]
# ## Example 2: Web Scraping & Visualization
#
# Now let's scrape data from a live website and create a beautiful, interactive visualization.
#
# We'll use **Hacker News** as an example — one of the most popular tech news sites.

# %%
# Scrape and visualize Hacker News
hn_url = "https://news.ycombinator.com"

widget_hn = vw.create(
    description="""
    Create an interactive Hacker News clone widget with the following features:
    - Display stories in a clean, modern card-based layout
    - Show story title (clickable link), author, score, comments count, and time
    - Sort stories by score (highest first) or time (newest first)
    - Filter stories by minimum score threshold using a slider
    - Highlight top stories (score > 100) with an orange accent
    - Use a modern, minimalist design with orange accents (#ff6600)
    - Make it responsive and interactive with smooth hover effects
    - Add a search box to filter stories by title keywords
    - Show story metadata (author, time, comments) in a clean format
    - Use clean typography with good readability
    """,
    data=hn_url,
    show_progress=True
)

print("\n🌐 Hacker News data scraped and visualized!")
# Out:
# Loading data from source: https://news.ycombinator.com
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://news.ycombinator.com                                                                         |
# ✓ | ⏱: 1.06s
# [SCRAPE].. ◆ https://news.ycombinator.com                                                                         |
# ✓ | ⏱: 0.05s
# [COMPLETE] ● https://news.ycombinator.com                                                                         |
# ✓ | ⏱: 1.11s
# Loading data... {'metadata': {'shape': (98, 3), 'columns': ['0', '1', '2'], 'dtypes': {'0': 'object', '1': 'object', '2': 'object'}, 'null_counts': {'0': 65, '1': 97, '2': 36}, 'sampled': False, 'original_rows': None}, 'sample': [{0: 'Hacker Newsnew | past | comments | ask | show | jobs | submitlogin', 1: nan, 2: nan}, {0: nan, 1: 'Hacker Newsnew | past | comments | ask | show | jobs | submit', 2: 'login'}, {0: nan, 1: nan, 2: nan}, {0: "1.DeepSeek-v3.2: Pushing the frontier of open large language models [pdf] (huggingface.co)155 points by pretext 2 hours ago | hide | 41\xa0comments2.India orders smartphone makers to preload state-owned cyber safety app (reuters.com)124 points by jmsflknr 2 hours ago | hide | 64\xa0comments3.Ask HN: Who is hiring? (December 2025)137 points by whoishiring 3 hours ago | hide | 162\xa0comments4.Ghostty compiled to WASM with xterm.js API compatibility (github.com/coder)34 points by kylecarbs 1 hour ago | hide | 4\xa0comments5.Intel could return to Apple computers in 2027 (theverge.com)21 points by DamnInteresting 54 minutes ago | hide | 18\xa0comments6.Why xor eax, eax? (xania.org)370 points by hasheddan 7 hours ago | hide | 143\xa0comments7.High-income job losses are cooling housing demand (jbrec.com)152 points by gmays 1 hour ago | hide | 149\xa0comments8.Isn't WSL2 just a VM? (ssg.dev)101 points by sedatk 4 hours ago | hide | 49\xa0comments9.Cartographers Have Been Hiding Covert Illustrations Inside of Switzerland's Maps (aiga.org)183 points by mhb 5 hours ago | hide | 40\xa0comments10.Ask HN: Who wants to be hired? (December 2025)49 points by whoishiring 3 hours ago | hide | 107\xa0comments11.Better Auth (YC X25) Is Hiring (ycombinator.com)2 hours ago | hide12.Better Than JSON (aloisdeniel.com)12 points by barremian 41 minutes ago | hide | 11\xa0comments13.Response to Ruby Is Not a Serious Programming Language (robbyonrails.com)69 points by robbyrussell 1 hour ago | hide | 51\xa0comments14.Search tool that only returns content created before ChatGPT's public release (tegabrain.com)767 points by dmitrygr 15 hours ago | hide | 308\xa0comments15.ImAnim: Modern animation capabilities to ImGui applications (github.com/soufianekhiat)50 points by klaussilveira 3 hours ago | hide | 12\xa0comments16.Durin is a library for reading and writing the Dwarf debugging format (github.com/tmcgilchrist)8 points by mooreds 1 hour ago | hide | discuss17.A vector graphics workstation from the 70s (justanotherelectronicsblog.com)103 points by ibobev 6 hours ago | hide | 17\xa0comments18.Self-hosting a Matrix server for 5 years (yaky.dev)202 points by the-anarchist 8 hours ago | hide | 88\xa0comments19.Google unkills JPEG XL? (tonisagrista.com)160 points by speckx 4 hours ago | hide | 141\xa0comments20.Historic Engineering Wonders: Photos That Reveal How They Pulled It Off (rarehistoricalphotos.com)93 points by dxs 6 hours ago | hide | 17\xa0comments21.I made a quieter air purifier (chillphysicsenjoyer.substack.com)98 points by crescit_eundo 7 hours ago | hide | 46\xa0comments22.Games using anti-cheats and their compatibility with GNU/Linux or Wine/Proton (areweanticheatyet.com)222 points by doener 12 hours ago | hide | 310\xa0comments23.React and Remix Choose Different Futures (laconicwit.com)3 points by surprisetalk 43 minutes ago | hide | discuss24.Langjam Gamejam: Build a programming language then make a game with it (langjamgamejam.com)102 points by birdculture 10 hours ago | hide | 46\xa0comments25.How we built the v0 iOS app (vercel.com)11 points by MaxLeiter 1 hour ago | hide | 15\xa0comments26.Spleen Monospaced Bitmap Fonts (github.com/fcambus)17 points by keyle 3 hours ago | hide | 5\xa0comments27.WordPress plugin quirk resulted in UK Gov OBR Budget leak [pdf] (obr.uk)102 points by robtaylor 4 hours ago | hide | 92\xa0comments28.It’s been a very hard year (bell.bz)308 points by surprisetalk 14 hours ago | hide | 407\xa0comments29.The Penicillin Myth (asimov.press)100 points by surprisetalk 5 hours ago | hid ...
# 0   Hacker Newsnew | past | comments | ask | show ...
# 1                                                 NaN
# 2                                                 NaN
# 3   1.DeepSeek-v3.2: Pushing the frontier of open ...
# 4                                                  1.
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96  Guidelines | FAQ | Lists | API | Security | Le...
# 97                                                NaN
#
#                                                     1  \
# 0                                                 NaN
# 1   Hacker Newsnew | past | comments | ask | show ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                     2
# 0                                                 NaN
# 1                                               login
# 2                                                 NaN
# 3                                                 NaN
# 4   DeepSeek-v3.2: Pushing the frontier of open la...
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                               More
# 96                                                NaN
# 97                                                NaN
#
# [98 rows x 3 columns]}
# 🌐 Hacker News data scraped and visualized!

# %% [markdown]
# ### What Just Happened?
#
# For web scraping, Vibe Widget:
# 1. 🌐 Detected the URL format
# 2. 🔍 Used WebExtractor with crawl4ai to scrape content
# 3. 📊 Parsed the HTML structure to extract story data
# 4. 🎨 Generated a custom React component matching your description
# 5. ✅ Rendered the interactive widget with all requested features
#
# Try interacting with the widget:
# - ✨ Search for keywords
# - 🔢 Sort by score or time
# - 🎚️ Filter by minimum score
# - 🖱️ Click titles to visit stories

# %% [markdown]
# ## Example 3: Scientific Data (NetCDF)
#
# Vibe Widget also supports scientific data formats like NetCDF, commonly used for climate and ocean data.

# %%
# Visualize sea surface temperature data
widget_netcdf = vw.create(
    "interactive heatmap showing sea surface temperature patterns, zoomable and pannable with color scale",
    "../testdata/20190722000000-OSPO-L4_GHRSST-SSTfnd-Geo_Polar_Blended-GLOB-v02.0-fv01.0.nc",
    show_progress=True
)

print("\n🌊 Sea surface temperature data visualized!")
# Out:
# Loading data from source: ../testdata/20190722000000-ospo-l4_ghrsst-sstfnd-geo_polar_blended-glob-v02.0-fv01.0.nc
# Loading data... {'metadata': {'shape': (10000, 7), 'columns': ['time', 'lat', 'lon', 'analysed_sst', 'analysis_error', 'sea_ice_fraction', 'mask'], 'dtypes': {'time': 'datetime64[ns]', 'lat': 'float32', 'lon': 'float32', 'analysed_sst': 'float32', 'analysis_error': 'float32', 'sea_ice_fraction': 'float32', 'mask': 'float32'}, 'null_counts': {'time': 0, 'lat': 0, 'lon': 0, 'analysed_sst': 3356, 'analysis_error': 3356, 'sea_ice_fraction': 0, 'mask': 0}, 'sampled': True, 'original_rows': None}, 'sample': [{'time': Timestamp('2019-07-22 12:00:00'), 'lat': -29.674999237060547, 'lon': -5.275000095367432, 'analysed_sst': 293.2699890136719, 'analysis_error': 0.12999999523162842, 'sea_ice_fraction': 0.0, 'mask': 1.0}, {'time': Timestamp('2019-07-22 12:00:00'), 'lat': -76.82499694824219, 'lon': -95.2750015258789, 'analysed_sst': nan, 'analysis_error': nan, 'sea_ice_fraction': 0.0, 'mask': 2.0}, {'time': Timestamp('2019-07-22 12:00:00'), 'lat': -5.775000095367432, 'lon': 72.42500305175781, 'analysed_sst': 301.04998779296875, 'analysis_error': 0.1599999964237213, 'sea_ice_fraction': 0.0, 'mask': 1.0}, {'time': Timestamp('2019-07-22 12:00:00'), 'lat': -38.67499923706055, 'lon': 130.47500610351562, 'analysed_sst': 285.0199890136719, 'analysis_error': 0.07999999821186066, 'sea_ice_fraction': 0.0, 'mask': 1.0}, {'time': Timestamp('2019-07-22 12:00:00'), 'lat': -82.92500305175781, 'lon': 21.125, 'analysed_sst': nan, 'analysis_error': nan, 'sea_ice_fraction': 0.0, 'mask': 2.0}], 'dataframe':                         time        lat         lon  analysed_sst  \
# 8686694  2019-07-22 12:00:00 -29.674999   -5.275000    293.269989
# 1895294  2019-07-22 12:00:00 -76.824997  -95.275002           NaN
# 12129848 2019-07-22 12:00:00  -5.775000   72.425003    301.049988
# 7393409  2019-07-22 12:00:00 -38.674999  130.475006    285.019989
# 1019222  2019-07-22 12:00:00 -82.925003   21.125000           NaN
# ...                      ...        ...         ...           ...
# 14215338 2019-07-22 12:00:00   8.725000  -53.075001    301.929993
# 1379883  2019-07-22 12:00:00 -80.425003   54.174999           NaN
# 16664374 2019-07-22 12:00:00  25.725000   -1.275000           NaN
# 19683272 2019-07-22 12:00:00  46.674999  103.625000           NaN
# 274789   2019-07-22 12:00:00 -88.074997 -120.525002           NaN
#
#           analysis_error  sea_ice_fraction  mask
# 8686694             0.13               0.0   1.0
# 1895294              NaN               0.0   2.0
# 12129848            0.16               0.0   1.0
# 7393409             0.08               0.0   1.0
# 1019222              NaN               0.0   2.0
# ...                  ...               ...   ...
# 14215338            0.06               0.0   1.0
# 1379883              NaN               0.0   2.0
# 16664374             NaN               0.0   2.0
# 19683272             NaN               0.0   2.0
# 274789               NaN               0.0   2.0
#
# [10000 rows x 7 columns]}
# Note: Data truncated to 5000 rows for visualization.
# 🌊 Sea surface temperature data visualized!

# %% [markdown]
# ## Example 4: XML Data (Earthquake Events)
#
# Let's visualize earthquake events from an XML file.

# %%
# Visualize earthquake timeline
widget_xml = vw.create(
    "timeline showing earthquake events over time with magnitude indicators and interactive tooltips",
    "../testdata/ANSS_ComCat.xml",
    show_progress=True
)

print("\n🌍 Earthquake timeline visualized!")
# Out:
# Loading data from source: ../testdata/anss_comcat.xml
# Loading data... {'metadata': {'shape': (1, 6), 'columns': ['idinfo', 'dataqual', 'spref', 'eainfo', 'distinfo', 'metainfo'], 'dtypes': {'idinfo': 'object', 'dataqual': 'object', 'spref': 'object', 'eainfo': 'object', 'distinfo': 'object', 'metainfo': 'object'}, 'null_counts': {'idinfo': 0, 'dataqual': 0, 'spref': 0, 'eainfo': 0, 'distinfo': 0, 'metainfo': 0}, 'sampled': False, 'original_rows': None}, 'sample': [{'idinfo': '\n    ', 'dataqual': '\n    ', 'spref': '\n    ', 'eainfo': '\n    ', 'distinfo': '\n    ', 'metainfo': '\n    '}], 'dataframe':    idinfo dataqual   spref  eainfo distinfo metainfo
# 0  \n       \n      \n      \n       \n       \n    }
# 🌍 Earthquake timeline visualized!

# %% [markdown]
# ## Summary
#
# In this notebook, we've seen how Vibe Widget handles multiple data formats seamlessly:
#
# | Format | Use Case | Extraction Method |
# |--------|----------|-------------------|
# | **PDF** | Reports, Tables | Automatic table extraction with camelot/pdfplumber |
# | **Web URLs** | Live data, News | Smart web scraping with crawl4ai |
# | **NetCDF** | Scientific data | Climate/ocean data analysis |
# | **XML** | Structured data | Earthquake events, feeds |
#
# ### Key Takeaways:
#
# ✨ **No Manual Parsing**: Just provide the file path or URL
# 🤖 **AI Understands Context**: Describe what you want in plain English
# 🎨 **Custom Visualizations**: Not limited to predefined chart types
# ⚡ **Fast Development**: From idea to interactive widget in seconds
#
# Next, check out [`cross_widget_interactions.ipynb`](cross_widget_interactions.ipynb) to see how widgets can communicate with each other!
