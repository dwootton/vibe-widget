# %% [markdown]
# # Tic-Tac-Toe (Actions + Outputs)
#
# This example loads a prebuilt widget and exercises the action interface.
# Click any square to place X, then run the next cell to trigger an AI move and read outputs.

# %%
import time
from pathlib import Path

import vibe_widget as vw

js_code = Path("examples/tic_tac_toe_widget.js").read_text()

widget = vw.create(
    "Tic-tac-toe with actions",
    outputs=vw.outputs(
        board_state="current board state",
        game_over="game over flag",
        current_turn="current player turn",
    ),
    actions=vw.actions(
        ai_move=vw.action("AI move", params={"index": "0-8"})
    ),
    display=True,
    cache=False,
)

widget.code = js_code
widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import time
#       2 from pathlib import Path
# ----> 4 import vibe_widget as vw
#       6 js_code = Path("examples/tic_tac_toe_widget.js").read_text()
#       8 widget = vw.create(
#       9     "Tic-tac-toe with actions",
#      10     outputs=vw.outputs(
#    (...)
#      19     cache=False,
#      20 )
#
# File ~/repos/vibe-widgets/src/vibe_widget/__init__.py:1
# ----> 1 from vibe_widget.core import VibeWidget, create, edit, load, clear, ComponentReference
#       2 from vibe_widget.api import outputs, inputs, output, actions, action, ExportHandle
#       3 from vibe_widget.config import config, Config, models
#
# File ~/repos/vibe-widgets/src/vibe_widget/core.py:46
#      36 from vibe_widget.utils.widget_store import WidgetStore
#      37 from vibe_widget.utils.audit_store import (
# ...

# %% [markdown]
# ## Simulate a turn change
#
# After you click a square (X move), run this cell to dispatch an AI move and verify outputs.

# %%
widget.actions.ai_move(index=4)
time.sleep(0.2)
widget.board_state, widget.current_turn, widget.game_over
